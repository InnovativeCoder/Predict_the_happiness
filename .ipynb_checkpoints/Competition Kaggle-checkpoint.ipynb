# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Compitetion Dataset/train.csv")

# %%
data.describe()
# Out:
#         User_ID                                        Description  \
# count     38932                                              38932
# unique    38932                                              38932
# top     id38616  Stayed two days in March for a corporate event...
# freq          1                                                  1
#
#        Browser_Used Device_Used Is_Response
# count         38932       38932       38932
# unique           11           3           2
# top         Firefox     Desktop       happy
# freq           7367       15026       26521

# %%
data.head()
# Out:
#    User_ID                                        Description  \
# 0  id10326  The room was kind of clean but had a VERY stro...
# 1  id10327  I stayed at the Crown Plaza April -- - April -...
# 2  id10328  I booked this hotel through Hotwire at the low...
# 3  id10329  Stayed here with husband and sons on the way t...
# 4  id10330  My girlfriends and I stayed here to celebrate ...
#
#         Browser_Used Device_Used Is_Response
# 0               Edge      Mobile   not happy
# 1  Internet Explorer      Mobile   not happy
# 2            Mozilla      Tablet   not happy
# 3   InternetExplorer     Desktop       happy
# 4               Edge      Tablet   not happy

# %%
del data['Browser_Used']
del data['Device_Used']

# %%
data.head()
# Out:
#    User_ID                                        Description Is_Response
# 0  id10326  The room was kind of clean but had a VERY stro...   not happy
# 1  id10327  I stayed at the Crown Plaza April -- - April -...   not happy
# 2  id10328  I booked this hotel through Hotwire at the low...   not happy
# 3  id10329  Stayed here with husband and sons on the way t...       happy
# 4  id10330  My girlfriends and I stayed here to celebrate ...   not happy

# %%
filtered = data['Description']

# %% [markdown]
# # Data Processing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import  PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
lemmatizer = WordNetLemmatizer()
stopw = set(stopwords.words("english"))
#stopw.update(".", "?", "(", ")", ",", "-","--", "'", '"',"/","2","1","3","4","5","6","7","8","9","10","&")

# %%
def text_to_words(raw_text):   #use stemming and stopwords as well, it will increase its accuracy
    
    pos_t = (pos_tag(word_tokenize(raw_text)))
    words = raw_text.lower()
    lemmatizer.lemmatize(words)
    words = words.split()
    meaningful_words = [w for w in words if not w in stopw]
    return (" ".join(meaningful_words))

# %%
temp = data['Description']

# %%
new = temp[:10].apply(text_to_words)

# %%
new
# Out:
# 0    room kind clean strong smell dogs. generally a...
# 1    stayed crown plaza april -- april --, ----. st...
# 2    booked hotel hotwire lowest price could find. ...
# 3    stayed husband sons way alaska cruise. loved h...
# 4    girlfriends stayed celebrate --th birthdays. p...
# 5    rooms. one nice clearly updated recently other...
# 6    husband stayed hotel times. though fanciest ho...
# 7    wife stayed glorious city back. sf expensive, ...
# 8    boyfriend stayed fairmont recent trip san fran...
# 9    wonderful staff, great location, definately pr...
# Name: Description, dtype: object

# %%
data['Description'] = data['Description'].apply(text_to_words)

# %%
data.head()
# Out:
#    User_ID                                        Description Is_Response
# 0  id10326  room kind clean strong smell dogs. generally a...   not happy
# 1  id10327  stayed crown plaza april -- april --, ----. st...   not happy
# 2  id10328  booked hotel hotwire lowest price could find. ...   not happy
# 3  id10329  stayed husband sons way alaska cruise. loved h...       happy
# 4  id10330  girlfriends stayed celebrate --th birthdays. p...   not happy

# %% [markdown]
# # Testing Data is loaded

# %%
data_test = pd.read_csv("Compitetion Dataset/test.csv")

# %%
data_test
# Out:
#         User_ID                                        Description  \
# 0       id80132  Looking for a motel in close proximity to TV t...
# 1       id80133  Walking distance to Madison Square Garden and ...
# 2       id80134  Visited Seattle on business. Spent - nights in...
# 3       id80135  This hotel location is excellent and the rooms...
# 4       id80136  This hotel is awesome I love the service Antho...
# 5       id80137  Rooms, concierge services and party scene were...
# 6       id80138  What a pleasant place to stay!\nThe hotel is b...
# 7       id80139  I booked out the same day I arrived. It cost m...
# 8       id80140  Unlike some hotels that grimace when you show ...
# 9       id80141  Hotel Sorella for my birthday. I absolutely lo...
# 10      id80142  I had a very comfortable stay at Baymont. It w...
# 11      id80143  This hotel is a keeper! First, you get a full ...
# 12      id80144  Really nice lobby, with free coffee, water, co...
# 13      id80145  There's a reason why so many of the previous r...
# 14      id80146  Great location, close to Times Square and so m...
# 15      id80147  We booked the Hampton for one night based on T...
# 16      id80148  I stayed here with my girlfriend who was atten...
# 17      id80149  From the location to service to amenities, thi...
# 18      id80150  my work sent me down to jacksonville - times t...
# 19      id80151  Stayed here for two nights while I visited DC ...
# 20      id80152  This was my first visit to this property. To b...
# 21      id80153  We thoroughly enjoyed our stay here. Close to ...
# 22      id80154  Can't say enough about our recent stay at Hote...
# 23      id80155  There are experiences in life that you embrace...
# 24      id80156  Reserved a King Suite at the Blackstone thinki...
# 25      id80157  This is not your typical Fairfield Inn archite...
# 26      id80158  This is the best place to stay in downtown Den...
# 27      id80159  This is - min away from Times Square, Central ...
# 28      id80160  Check in to check out, the Clift provided a fe...
# 29      id80161  I write this letter to tripadvisor users to sa...
# ...         ...                                                ...
# 29374  id109506  the palomar was a nice hotel. nothing special,...
# 29375  id109507  For the most part this was a very good hotel. ...
# 29376  id109508  We booked the hotel through priceline and were...
# 29377  id109509  Paying a top price for a room but having to pa...
# 29378  id109510  Stayed here in March ---- . In San Antonio for...
# 29379  id109511  It is in a really convenient location. Walking...
# 29380  id109512  The rooms were very clean. \nThe staff went ab...
# 29381  id109513  -:The phone in living area not working( not fi...
# 29382  id109514  Have travelled throughout the world for work a...
# 29383  id109515  We got a too-good-to-be-true rate from a motor...
# 29384  id109516  I just got back this morning from New York and...
# 29385  id109517  We booked a double hotal room, arrived late to...
# 29386  id109518  It was too high but maybe that's the going rat...
# 29387  id109519  This property always comes through with the de...
# 29388  id109520  My husband and I frequently this hotel and we ...
# 29389  id109521  This hotel is a great location for a day or - ...
# 29390  id109522  My husband and I spend Labor Day weekend in NY...
# 29391  id109523  I had no problem with the hotel or the room it...
# 29392  id109524  Hotel Icon is a well-designed hotel built in a...
# 29393  id109525  I booked the Hotel Tomo because I got a good (...
# 29394  id109526  This hotel may not be the most glamorous in SF...
# 29395  id109527  Stayed here for - nights & had a room overlook...
# 29396  id109528  We stayed for three nights (June ----). The lo...
# 29397  id109529  We spent - nights in a king castia. The beds a...
# 29398  id109530  We booked our flight-hotel package on Expedia ...
# 29399  id109531  I stayed at the hotel and towers for a confere...
# 29400  id109532  Trying to stay within the Marriott family and ...
# 29401  id109533  We stayed for - nights with our little dog,ver...
# 29402  id109534  Stayed at the Yotel over the weekend and was v...
# 29403  id109535  The Blakely is is comfortable is every way: th...
#
#             Browser_Used Device_Used
# 0                Firefox      Mobile
# 1       InternetExplorer     Desktop
# 2                     IE      Tablet
# 3                   Edge      Mobile
# 4                Mozilla      Mobile
# 5       InternetExplorer      Tablet
# 6                  Opera      Tablet
# 7                   Edge     Desktop
# 8          Google Chrome      Tablet
# 9          Google Chrome      Mobile
# 10       Mozilla Firefox      Tablet
# 11               Mozilla      Mobile
# 12       Mozilla Firefox      Mobile
# 13      InternetExplorer     Desktop
# 14       Mozilla Firefox      Tablet
# 15               Mozilla      Tablet
# 16                  Edge      Tablet
# 17       Mozilla Firefox      Mobile
# 18               Mozilla      Tablet
# 19       Mozilla Firefox      Tablet
# 20         Google Chrome      Tablet
# 21       Mozilla Firefox      Mobile
# 22               Firefox      Mobile
# 23                  Edge      Mobile
# 24                  Edge      Mobile
# 25       Mozilla Firefox     Desktop
# 26               Mozilla      Tablet
# 27       Mozilla Firefox      Mobile
# 28     Internet Explorer      Mobile
# 29                  Edge      Mobile
# ...                  ...         ...
# 29374               Edge     Desktop
# 29375   InternetExplorer     Desktop
# 29376               Edge      Tablet
# 29377    Mozilla Firefox      Mobile
# 29378   InternetExplorer      Mobile
# 29379               Edge      Tablet
# 29380  Internet Explorer      Mobile
# 29381               Edge     Desktop
# 29382            Mozilla      Mobile
# 29383    Mozilla Firefox      Mobile
# 29384   InternetExplorer      Mobile
# 29385   InternetExplorer      Mobile
# 29386               Edge     Desktop
# 29387               Edge      Tablet
# 29388      Google Chrome     Desktop
# 29389               Edge      Tablet
# 29390   InternetExplorer      Mobile
# 29391    Mozilla Firefox      Mobile
# 29392      Google Chrome      Mobile
# 29393  Internet Explorer      Tablet
# 29394            Firefox     Desktop
# 29395               Edge      Mobile
# 29396            Firefox     Desktop
# 29397            Firefox      Tablet
# 29398            Mozilla      Mobile
# 29399             Chrome      Mobile
# 29400  Internet Explorer      Tablet
# 29401               Edge     Desktop
# 29402   InternetExplorer     Desktop
# 29403    Mozilla Firefox      Mobile
#
# [29404 rows x 4 columns]

# %%
Given_pred = ['happy', 'not_happy','not_happy','not_happy','happy']

# %%
Given_pred = pd.DataFrame(Given_pred)

# %%
data_test['Given_pred'] = Given_pred

# %%
data_test
# Out:
#         User_ID                                        Description  \
# 0       id80132  Looking for a motel in close proximity to TV t...
# 1       id80133  Walking distance to Madison Square Garden and ...
# 2       id80134  Visited Seattle on business. Spent - nights in...
# 3       id80135  This hotel location is excellent and the rooms...
# 4       id80136  This hotel is awesome I love the service Antho...
# 5       id80137  Rooms, concierge services and party scene were...
# 6       id80138  What a pleasant place to stay!\nThe hotel is b...
# 7       id80139  I booked out the same day I arrived. It cost m...
# 8       id80140  Unlike some hotels that grimace when you show ...
# 9       id80141  Hotel Sorella for my birthday. I absolutely lo...
# 10      id80142  I had a very comfortable stay at Baymont. It w...
# 11      id80143  This hotel is a keeper! First, you get a full ...
# 12      id80144  Really nice lobby, with free coffee, water, co...
# 13      id80145  There's a reason why so many of the previous r...
# 14      id80146  Great location, close to Times Square and so m...
# 15      id80147  We booked the Hampton for one night based on T...
# 16      id80148  I stayed here with my girlfriend who was atten...
# 17      id80149  From the location to service to amenities, thi...
# 18      id80150  my work sent me down to jacksonville - times t...
# 19      id80151  Stayed here for two nights while I visited DC ...
# 20      id80152  This was my first visit to this property. To b...
# 21      id80153  We thoroughly enjoyed our stay here. Close to ...
# 22      id80154  Can't say enough about our recent stay at Hote...
# 23      id80155  There are experiences in life that you embrace...
# 24      id80156  Reserved a King Suite at the Blackstone thinki...
# 25      id80157  This is not your typical Fairfield Inn archite...
# 26      id80158  This is the best place to stay in downtown Den...
# 27      id80159  This is - min away from Times Square, Central ...
# 28      id80160  Check in to check out, the Clift provided a fe...
# 29      id80161  I write this letter to tripadvisor users to sa...
# ...         ...                                                ...
# 29374  id109506  the palomar was a nice hotel. nothing special,...
# 29375  id109507  For the most part this was a very good hotel. ...
# 29376  id109508  We booked the hotel through priceline and were...
# 29377  id109509  Paying a top price for a room but having to pa...
# 29378  id109510  Stayed here in March ---- . In San Antonio for...
# 29379  id109511  It is in a really convenient location. Walking...
# 29380  id109512  The rooms were very clean. \nThe staff went ab...
# 29381  id109513  -:The phone in living area not working( not fi...
# 29382  id109514  Have travelled throughout the world for work a...
# 29383  id109515  We got a too-good-to-be-true rate from a motor...
# 29384  id109516  I just got back this morning from New York and...
# 29385  id109517  We booked a double hotal room, arrived late to...
# 29386  id109518  It was too high but maybe that's the going rat...
# 29387  id109519  This property always comes through with the de...
# 29388  id109520  My husband and I frequently this hotel and we ...
# 29389  id109521  This hotel is a great location for a day or - ...
# 29390  id109522  My husband and I spend Labor Day weekend in NY...
# 29391  id109523  I had no problem with the hotel or the room it...
# 29392  id109524  Hotel Icon is a well-designed hotel built in a...
# 29393  id109525  I booked the Hotel Tomo because I got a good (...
# 29394  id109526  This hotel may not be the most glamorous in SF...
# 29395  id109527  Stayed here for - nights & had a room overlook...
# 29396  id109528  We stayed for three nights (June ----). The lo...
# 29397  id109529  We spent - nights in a king castia. The beds a...
# 29398  id109530  We booked our flight-hotel package on Expedia ...
# 29399  id109531  I stayed at the hotel and towers for a confere...
# 29400  id109532  Trying to stay within the Marriott family and ...
# 29401  id109533  We stayed for - nights with our little dog,ver...
# 29402  id109534  Stayed at the Yotel over the weekend and was v...
# 29403  id109535  The Blakely is is comfortable is every way: th...
#
#             Browser_Used Device_Used Given_pred
# 0                Firefox      Mobile      happy
# 1       InternetExplorer     Desktop  not_happy
# 2                     IE      Tablet  not_happy
# 3                   Edge      Mobile  not_happy
# 4                Mozilla      Mobile      happy
# 5       InternetExplorer      Tablet        NaN
# 6                  Opera      Tablet        NaN
# 7                   Edge     Desktop        NaN
# 8          Google Chrome      Tablet        NaN
# 9          Google Chrome      Mobile        NaN
# 10       Mozilla Firefox      Tablet        NaN
# 11               Mozilla      Mobile        NaN
# 12       Mozilla Firefox      Mobile        NaN
# 13      InternetExplorer     Desktop        NaN
# 14       Mozilla Firefox      Tablet        NaN
# 15               Mozilla      Tablet        NaN
# 16                  Edge      Tablet        NaN
# 17       Mozilla Firefox      Mobile        NaN
# 18               Mozilla      Tablet        NaN
# 19       Mozilla Firefox      Tablet        NaN
# 20         Google Chrome      Tablet        NaN
# 21       Mozilla Firefox      Mobile        NaN
# 22               Firefox      Mobile        NaN
# 23                  Edge      Mobile        NaN
# 24                  Edge      Mobile        NaN
# 25       Mozilla Firefox     Desktop        NaN
# 26               Mozilla      Tablet        NaN
# 27       Mozilla Firefox      Mobile        NaN
# 28     Internet Explorer      Mobile        NaN
# 29                  Edge      Mobile        NaN
# ...                  ...         ...        ...
# 29374               Edge     Desktop        NaN
# 29375   InternetExplorer     Desktop        NaN
# 29376               Edge      Tablet        NaN
# 29377    Mozilla Firefox      Mobile        NaN
# 29378   InternetExplorer      Mobile        NaN
# 29379               Edge      Tablet        NaN
# 29380  Internet Explorer      Mobile        NaN
# 29381               Edge     Desktop        NaN
# 29382            Mozilla      Mobile        NaN
# 29383    Mozilla Firefox      Mobile        NaN
# 29384   InternetExplorer      Mobile        NaN
# 29385   InternetExplorer      Mobile        NaN
# 29386               Edge     Desktop        NaN
# 29387               Edge      Tablet        NaN
# 29388      Google Chrome     Desktop        NaN
# 29389               Edge      Tablet        NaN
# 29390   InternetExplorer      Mobile        NaN
# 29391    Mozilla Firefox      Mobile        NaN
# 29392      Google Chrome      Mobile        NaN
# 29393  Internet Explorer      Tablet        NaN
# 29394            Firefox     Desktop        NaN
# 29395               Edge      Mobile        NaN
# 29396            Firefox     Desktop        NaN
# 29397            Firefox      Tablet        NaN
# 29398            Mozilla      Mobile        NaN
# 29399             Chrome      Mobile        NaN
# 29400  Internet Explorer      Tablet        NaN
# 29401               Edge     Desktop        NaN
# 29402   InternetExplorer     Desktop        NaN
# 29403    Mozilla Firefox      Mobile        NaN
#
# [29404 rows x 5 columns]

# %% [markdown]
# # Classification

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
v = CountVectorizer(analyzer = "word", ngram_range = (1,2))

# %%
train_features = v.fit_transform(data['Description'])

# %%
test_features = v.transform(data_test['Description'])

# %%
y_train = data['Is_Response']

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier()
clf.fit(train_features, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
pred = clf.predict(test_features)   #57% accuracy is achieved

# %%
data_test['predicted'] = pred

# %%
data_test  #best approach yet
# Out:
#         User_ID                                        Description  \
# 0       id80132  Looking for a motel in close proximity to TV t...
# 1       id80133  Walking distance to Madison Square Garden and ...
# 2       id80134  Visited Seattle on business. Spent - nights in...
# 3       id80135  This hotel location is excellent and the rooms...
# 4       id80136  This hotel is awesome I love the service Antho...
# 5       id80137  Rooms, concierge services and party scene were...
# 6       id80138  What a pleasant place to stay!\nThe hotel is b...
# 7       id80139  I booked out the same day I arrived. It cost m...
# 8       id80140  Unlike some hotels that grimace when you show ...
# 9       id80141  Hotel Sorella for my birthday. I absolutely lo...
# 10      id80142  I had a very comfortable stay at Baymont. It w...
# 11      id80143  This hotel is a keeper! First, you get a full ...
# 12      id80144  Really nice lobby, with free coffee, water, co...
# 13      id80145  There's a reason why so many of the previous r...
# 14      id80146  Great location, close to Times Square and so m...
# 15      id80147  We booked the Hampton for one night based on T...
# 16      id80148  I stayed here with my girlfriend who was atten...
# 17      id80149  From the location to service to amenities, thi...
# 18      id80150  my work sent me down to jacksonville - times t...
# 19      id80151  Stayed here for two nights while I visited DC ...
# 20      id80152  This was my first visit to this property. To b...
# 21      id80153  We thoroughly enjoyed our stay here. Close to ...
# 22      id80154  Can't say enough about our recent stay at Hote...
# 23      id80155  There are experiences in life that you embrace...
# 24      id80156  Reserved a King Suite at the Blackstone thinki...
# 25      id80157  This is not your typical Fairfield Inn archite...
# 26      id80158  This is the best place to stay in downtown Den...
# 27      id80159  This is - min away from Times Square, Central ...
# 28      id80160  Check in to check out, the Clift provided a fe...
# 29      id80161  I write this letter to tripadvisor users to sa...
# ...         ...                                                ...
# 29374  id109506  the palomar was a nice hotel. nothing special,...
# 29375  id109507  For the most part this was a very good hotel. ...
# 29376  id109508  We booked the hotel through priceline and were...
# 29377  id109509  Paying a top price for a room but having to pa...
# 29378  id109510  Stayed here in March ---- . In San Antonio for...
# 29379  id109511  It is in a really convenient location. Walking...
# 29380  id109512  The rooms were very clean. \nThe staff went ab...
# 29381  id109513  -:The phone in living area not working( not fi...
# 29382  id109514  Have travelled throughout the world for work a...
# 29383  id109515  We got a too-good-to-be-true rate from a motor...
# 29384  id109516  I just got back this morning from New York and...
# 29385  id109517  We booked a double hotal room, arrived late to...
# 29386  id109518  It was too high but maybe that's the going rat...
# 29387  id109519  This property always comes through with the de...
# 29388  id109520  My husband and I frequently this hotel and we ...
# 29389  id109521  This hotel is a great location for a day or - ...
# 29390  id109522  My husband and I spend Labor Day weekend in NY...
# 29391  id109523  I had no problem with the hotel or the room it...
# 29392  id109524  Hotel Icon is a well-designed hotel built in a...
# 29393  id109525  I booked the Hotel Tomo because I got a good (...
# 29394  id109526  This hotel may not be the most glamorous in SF...
# 29395  id109527  Stayed here for - nights & had a room overlook...
# 29396  id109528  We stayed for three nights (June ----). The lo...
# 29397  id109529  We spent - nights in a king castia. The beds a...
# 29398  id109530  We booked our flight-hotel package on Expedia ...
# 29399  id109531  I stayed at the hotel and towers for a confere...
# 29400  id109532  Trying to stay within the Marriott family and ...
# 29401  id109533  We stayed for - nights with our little dog,ver...
# 29402  id109534  Stayed at the Yotel over the weekend and was v...
# 29403  id109535  The Blakely is is comfortable is every way: th...
#
#             Browser_Used Device_Used Given_pred  predicted
# 0                Firefox      Mobile      happy  not happy
# 1       InternetExplorer     Desktop  not_happy      happy
# 2                     IE      Tablet  not_happy      happy
# 3                   Edge      Mobile  not_happy      happy
# 4                Mozilla      Mobile      happy      happy
# 5       InternetExplorer      Tablet        NaN      happy
# 6                  Opera      Tablet        NaN      happy
# 7                   Edge     Desktop        NaN  not happy
# 8          Google Chrome      Tablet        NaN  not happy
# 9          Google Chrome      Mobile        NaN      happy
# 10       Mozilla Firefox      Tablet        NaN      happy
# 11               Mozilla      Mobile        NaN  not happy
# 12       Mozilla Firefox      Mobile        NaN  not happy
# 13      InternetExplorer     Desktop        NaN  not happy
# 14       Mozilla Firefox      Tablet        NaN      happy
# 15               Mozilla      Tablet        NaN      happy
# 16                  Edge      Tablet        NaN      happy
# 17       Mozilla Firefox      Mobile        NaN      happy
# 18               Mozilla      Tablet        NaN      happy
# 19       Mozilla Firefox      Tablet        NaN      happy
# 20         Google Chrome      Tablet        NaN      happy
# 21       Mozilla Firefox      Mobile        NaN      happy
# 22               Firefox      Mobile        NaN      happy
# 23                  Edge      Mobile        NaN      happy
# 24                  Edge      Mobile        NaN      happy
# 25       Mozilla Firefox     Desktop        NaN  not happy
# 26               Mozilla      Tablet        NaN      happy
# 27       Mozilla Firefox      Mobile        NaN      happy
# 28     Internet Explorer      Mobile        NaN      happy
# 29                  Edge      Mobile        NaN  not happy
# ...                  ...         ...        ...        ...
# 29374               Edge     Desktop        NaN  not happy
# 29375   InternetExplorer     Desktop        NaN  not happy
# 29376               Edge      Tablet        NaN      happy
# 29377    Mozilla Firefox      Mobile        NaN      happy
# 29378   InternetExplorer      Mobile        NaN      happy
# 29379               Edge      Tablet        NaN      happy
# 29380  Internet Explorer      Mobile        NaN      happy
# 29381               Edge     Desktop        NaN  not happy
# 29382            Mozilla      Mobile        NaN  not happy
# 29383    Mozilla Firefox      Mobile        NaN      happy
# 29384   InternetExplorer      Mobile        NaN  not happy
# 29385   InternetExplorer      Mobile        NaN  not happy
# 29386               Edge     Desktop        NaN  not happy
# 29387               Edge      Tablet        NaN      happy
# 29388      Google Chrome     Desktop        NaN      happy
# 29389               Edge      Tablet        NaN  not happy
# 29390   InternetExplorer      Mobile        NaN      happy
# 29391    Mozilla Firefox      Mobile        NaN  not happy
# 29392      Google Chrome      Mobile        NaN      happy
# 29393  Internet Explorer      Tablet        NaN      happy
# 29394            Firefox     Desktop        NaN      happy
# 29395               Edge      Mobile        NaN  not happy
# 29396            Firefox     Desktop        NaN  not happy
# 29397            Firefox      Tablet        NaN      happy
# 29398            Mozilla      Mobile        NaN      happy
# 29399             Chrome      Mobile        NaN      happy
# 29400  Internet Explorer      Tablet        NaN  not happy
# 29401               Edge     Desktop        NaN      happy
# 29402   InternetExplorer     Desktop        NaN      happy
# 29403    Mozilla Firefox      Mobile        NaN      happy
#
# [29404 rows x 6 columns]

# %%
predicted = data_test['User_ID']

# %%
predicted = pd.DataFrame(predicted)

# %%
predicted['predicted'] = data_test['predicted']

# %%
predicted.head()
# Out:
#    User_ID  predicted
# 0  id80132  not happy
# 1  id80133      happy
# 2  id80134      happy
# 3  id80135      happy
# 4  id80136      happy

# %%
predicted = data_test['User_ID']
predicted = pd.DataFrame(predicted)
predicted['predicted'] = data_test['predicted']

# %%
np.savetxt("predictions.csv",predicted, delimiter=",", fmt='%s')

# %%
#TF_IDF is not a good method for this dataset

# %%
from sklearn.neural_network import MLPClassifier

# %%
clf_n = MLPClassifier(hidden_layer_sizes = (18,10) ,solver='sgd')
clf_n.fit(train_features,y_train)
# Out:
# /Users/DBRSJ/anaconda/envs/tf_env/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:565: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(4, 3), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False)

# %%
pred = clf_n.predict(test_features)

# %%
data_test['predicted_mlp'] = pred

# %%
data_test
# Out:
#         User_ID                                        Description  \
# 0       id80132  Looking for a motel in close proximity to TV t...
# 1       id80133  Walking distance to Madison Square Garden and ...
# 2       id80134  Visited Seattle on business. Spent - nights in...
# 3       id80135  This hotel location is excellent and the rooms...
# 4       id80136  This hotel is awesome I love the service Antho...
# 5       id80137  Rooms, concierge services and party scene were...
# 6       id80138  What a pleasant place to stay!\nThe hotel is b...
# 7       id80139  I booked out the same day I arrived. It cost m...
# 8       id80140  Unlike some hotels that grimace when you show ...
# 9       id80141  Hotel Sorella for my birthday. I absolutely lo...
# 10      id80142  I had a very comfortable stay at Baymont. It w...
# 11      id80143  This hotel is a keeper! First, you get a full ...
# 12      id80144  Really nice lobby, with free coffee, water, co...
# 13      id80145  There's a reason why so many of the previous r...
# 14      id80146  Great location, close to Times Square and so m...
# 15      id80147  We booked the Hampton for one night based on T...
# 16      id80148  I stayed here with my girlfriend who was atten...
# 17      id80149  From the location to service to amenities, thi...
# 18      id80150  my work sent me down to jacksonville - times t...
# 19      id80151  Stayed here for two nights while I visited DC ...
# 20      id80152  This was my first visit to this property. To b...
# 21      id80153  We thoroughly enjoyed our stay here. Close to ...
# 22      id80154  Can't say enough about our recent stay at Hote...
# 23      id80155  There are experiences in life that you embrace...
# 24      id80156  Reserved a King Suite at the Blackstone thinki...
# 25      id80157  This is not your typical Fairfield Inn archite...
# 26      id80158  This is the best place to stay in downtown Den...
# 27      id80159  This is - min away from Times Square, Central ...
# 28      id80160  Check in to check out, the Clift provided a fe...
# 29      id80161  I write this letter to tripadvisor users to sa...
# ...         ...                                                ...
# 29374  id109506  the palomar was a nice hotel. nothing special,...
# 29375  id109507  For the most part this was a very good hotel. ...
# 29376  id109508  We booked the hotel through priceline and were...
# 29377  id109509  Paying a top price for a room but having to pa...
# 29378  id109510  Stayed here in March ---- . In San Antonio for...
# 29379  id109511  It is in a really convenient location. Walking...
# 29380  id109512  The rooms were very clean. \nThe staff went ab...
# 29381  id109513  -:The phone in living area not working( not fi...
# 29382  id109514  Have travelled throughout the world for work a...
# 29383  id109515  We got a too-good-to-be-true rate from a motor...
# 29384  id109516  I just got back this morning from New York and...
# 29385  id109517  We booked a double hotal room, arrived late to...
# 29386  id109518  It was too high but maybe that's the going rat...
# 29387  id109519  This property always comes through with the de...
# 29388  id109520  My husband and I frequently this hotel and we ...
# 29389  id109521  This hotel is a great location for a day or - ...
# 29390  id109522  My husband and I spend Labor Day weekend in NY...
# 29391  id109523  I had no problem with the hotel or the room it...
# 29392  id109524  Hotel Icon is a well-designed hotel built in a...
# 29393  id109525  I booked the Hotel Tomo because I got a good (...
# 29394  id109526  This hotel may not be the most glamorous in SF...
# 29395  id109527  Stayed here for - nights & had a room overlook...
# 29396  id109528  We stayed for three nights (June ----). The lo...
# 29397  id109529  We spent - nights in a king castia. The beds a...
# 29398  id109530  We booked our flight-hotel package on Expedia ...
# 29399  id109531  I stayed at the hotel and towers for a confere...
# 29400  id109532  Trying to stay within the Marriott family and ...
# 29401  id109533  We stayed for - nights with our little dog,ver...
# 29402  id109534  Stayed at the Yotel over the weekend and was v...
# 29403  id109535  The Blakely is is comfortable is every way: th...
#
#             Browser_Used Device_Used Given_pred  predicted predicted_mlp
# 0                Firefox      Mobile      happy  not happy     not happy
# 1       InternetExplorer     Desktop  not_happy      happy         happy
# 2                     IE      Tablet  not_happy      happy     not happy
# 3                   Edge      Mobile  not_happy  not happy     not happy
# 4                Mozilla      Mobile      happy      happy         happy
# 5       InternetExplorer      Tablet        NaN      happy         happy
# 6                  Opera      Tablet        NaN      happy         happy
# 7                   Edge     Desktop        NaN  not happy     not happy
# 8          Google Chrome      Tablet        NaN      happy         happy
# 9          Google Chrome      Mobile        NaN      happy         happy
# 10       Mozilla Firefox      Tablet        NaN      happy         happy
# 11               Mozilla      Mobile        NaN      happy         happy
# 12       Mozilla Firefox      Mobile        NaN      happy     not happy
# 13      InternetExplorer     Desktop        NaN  not happy     not happy
# 14       Mozilla Firefox      Tablet        NaN      happy     not happy
# 15               Mozilla      Tablet        NaN      happy     not happy
# 16                  Edge      Tablet        NaN      happy         happy
# 17       Mozilla Firefox      Mobile        NaN      happy         happy
# 18               Mozilla      Tablet        NaN      happy     not happy
# 19       Mozilla Firefox      Tablet        NaN      happy         happy
# 20         Google Chrome      Tablet        NaN      happy         happy
# 21       Mozilla Firefox      Mobile        NaN      happy         happy
# 22               Firefox      Mobile        NaN      happy         happy
# 23                  Edge      Mobile        NaN  not happy     not happy
# 24                  Edge      Mobile        NaN  not happy     not happy
# 25       Mozilla Firefox     Desktop        NaN  not happy     not happy
# 26               Mozilla      Tablet        NaN      happy         happy
# 27       Mozilla Firefox      Mobile        NaN  not happy     not happy
# 28     Internet Explorer      Mobile        NaN      happy         happy
# 29                  Edge      Mobile        NaN  not happy     not happy
# ...                  ...         ...        ...        ...           ...
# 29374               Edge     Desktop        NaN      happy     not happy
# 29375   InternetExplorer     Desktop        NaN  not happy     not happy
# 29376               Edge      Tablet        NaN  not happy     not happy
# 29377    Mozilla Firefox      Mobile        NaN      happy     not happy
# 29378   InternetExplorer      Mobile        NaN      happy         happy
# 29379               Edge      Tablet        NaN      happy     not happy
# 29380  Internet Explorer      Mobile        NaN      happy         happy
# 29381               Edge     Desktop        NaN  not happy     not happy
# 29382            Mozilla      Mobile        NaN  not happy     not happy
# 29383    Mozilla Firefox      Mobile        NaN      happy         happy
# 29384   InternetExplorer      Mobile        NaN      happy         happy
# 29385   InternetExplorer      Mobile        NaN  not happy     not happy
# 29386               Edge     Desktop        NaN  not happy     not happy
# 29387               Edge      Tablet        NaN      happy         happy
# 29388      Google Chrome     Desktop        NaN      happy         happy
# 29389               Edge      Tablet        NaN      happy         happy
# 29390   InternetExplorer      Mobile        NaN      happy         happy
# 29391    Mozilla Firefox      Mobile        NaN  not happy     not happy
# 29392      Google Chrome      Mobile        NaN      happy         happy
# 29393  Internet Explorer      Tablet        NaN      happy         happy
# 29394            Firefox     Desktop        NaN      happy         happy
# 29395               Edge      Mobile        NaN  not happy     not happy
# 29396            Firefox     Desktop        NaN      happy         happy
# 29397            Firefox      Tablet        NaN      happy         happy
# 29398            Mozilla      Mobile        NaN      happy         happy
# 29399             Chrome      Mobile        NaN      happy         happy
# 29400  Internet Explorer      Tablet        NaN      happy         happy
# 29401               Edge     Desktop        NaN      happy         happy
# 29402   InternetExplorer     Desktop        NaN      happy         happy
# 29403    Mozilla Firefox      Mobile        NaN      happy         happy
#
# [29404 rows x 7 columns]

# %%
predicted = data_test['User_ID']
predicted = pd.DataFrame(predicted)
predicted['predicted'] = data_test['predicted_mlp']

# %%
np.savetxt("predictions.csv",predicted, delimiter=",", fmt='%s')

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
clf = MultinomialNB()
clf.fit(train_features, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
pred = clf.predict(test_features)

# %%
pred = pd.DataFrame(pred)

# %%
pred.head()
# Out:
#            0
# 0  not happy
# 1      happy
# 2      happy
# 3  not happy
# 4      happy

# %%
data_test['predicted'] = pred

# %%
data_test
# Out:
#         User_ID                                        Description  \
# 0       id80132  Looking for a motel in close proximity to TV t...
# 1       id80133  Walking distance to Madison Square Garden and ...
# 2       id80134  Visited Seattle on business. Spent - nights in...
# 3       id80135  This hotel location is excellent and the rooms...
# 4       id80136  This hotel is awesome I love the service Antho...
# 5       id80137  Rooms, concierge services and party scene were...
# 6       id80138  What a pleasant place to stay!\nThe hotel is b...
# 7       id80139  I booked out the same day I arrived. It cost m...
# 8       id80140  Unlike some hotels that grimace when you show ...
# 9       id80141  Hotel Sorella for my birthday. I absolutely lo...
# 10      id80142  I had a very comfortable stay at Baymont. It w...
# 11      id80143  This hotel is a keeper! First, you get a full ...
# 12      id80144  Really nice lobby, with free coffee, water, co...
# 13      id80145  There's a reason why so many of the previous r...
# 14      id80146  Great location, close to Times Square and so m...
# 15      id80147  We booked the Hampton for one night based on T...
# 16      id80148  I stayed here with my girlfriend who was atten...
# 17      id80149  From the location to service to amenities, thi...
# 18      id80150  my work sent me down to jacksonville - times t...
# 19      id80151  Stayed here for two nights while I visited DC ...
# 20      id80152  This was my first visit to this property. To b...
# 21      id80153  We thoroughly enjoyed our stay here. Close to ...
# 22      id80154  Can't say enough about our recent stay at Hote...
# 23      id80155  There are experiences in life that you embrace...
# 24      id80156  Reserved a King Suite at the Blackstone thinki...
# 25      id80157  This is not your typical Fairfield Inn archite...
# 26      id80158  This is the best place to stay in downtown Den...
# 27      id80159  This is - min away from Times Square, Central ...
# 28      id80160  Check in to check out, the Clift provided a fe...
# 29      id80161  I write this letter to tripadvisor users to sa...
# ...         ...                                                ...
# 29374  id109506  the palomar was a nice hotel. nothing special,...
# 29375  id109507  For the most part this was a very good hotel. ...
# 29376  id109508  We booked the hotel through priceline and were...
# 29377  id109509  Paying a top price for a room but having to pa...
# 29378  id109510  Stayed here in March ---- . In San Antonio for...
# 29379  id109511  It is in a really convenient location. Walking...
# 29380  id109512  The rooms were very clean. \nThe staff went ab...
# 29381  id109513  -:The phone in living area not working( not fi...
# 29382  id109514  Have travelled throughout the world for work a...
# 29383  id109515  We got a too-good-to-be-true rate from a motor...
# 29384  id109516  I just got back this morning from New York and...
# 29385  id109517  We booked a double hotal room, arrived late to...
# 29386  id109518  It was too high but maybe that's the going rat...
# 29387  id109519  This property always comes through with the de...
# 29388  id109520  My husband and I frequently this hotel and we ...
# 29389  id109521  This hotel is a great location for a day or - ...
# 29390  id109522  My husband and I spend Labor Day weekend in NY...
# 29391  id109523  I had no problem with the hotel or the room it...
# 29392  id109524  Hotel Icon is a well-designed hotel built in a...
# 29393  id109525  I booked the Hotel Tomo because I got a good (...
# 29394  id109526  This hotel may not be the most glamorous in SF...
# 29395  id109527  Stayed here for - nights & had a room overlook...
# 29396  id109528  We stayed for three nights (June ----). The lo...
# 29397  id109529  We spent - nights in a king castia. The beds a...
# 29398  id109530  We booked our flight-hotel package on Expedia ...
# 29399  id109531  I stayed at the hotel and towers for a confere...
# 29400  id109532  Trying to stay within the Marriott family and ...
# 29401  id109533  We stayed for - nights with our little dog,ver...
# 29402  id109534  Stayed at the Yotel over the weekend and was v...
# 29403  id109535  The Blakely is is comfortable is every way: th...
#
#             Browser_Used Device_Used Given_pred  predicted predicted_mlp
# 0                Firefox      Mobile      happy  not happy     not happy
# 1       InternetExplorer     Desktop  not_happy      happy         happy
# 2                     IE      Tablet  not_happy      happy     not happy
# 3                   Edge      Mobile  not_happy  not happy     not happy
# 4                Mozilla      Mobile      happy      happy         happy
# 5       InternetExplorer      Tablet        NaN      happy         happy
# 6                  Opera      Tablet        NaN      happy         happy
# 7                   Edge     Desktop        NaN  not happy     not happy
# 8          Google Chrome      Tablet        NaN      happy         happy
# 9          Google Chrome      Mobile        NaN      happy         happy
# 10       Mozilla Firefox      Tablet        NaN      happy         happy
# 11               Mozilla      Mobile        NaN      happy         happy
# 12       Mozilla Firefox      Mobile        NaN      happy     not happy
# 13      InternetExplorer     Desktop        NaN  not happy     not happy
# 14       Mozilla Firefox      Tablet        NaN      happy     not happy
# 15               Mozilla      Tablet        NaN      happy     not happy
# 16                  Edge      Tablet        NaN      happy         happy
# 17       Mozilla Firefox      Mobile        NaN      happy         happy
# 18               Mozilla      Tablet        NaN      happy     not happy
# 19       Mozilla Firefox      Tablet        NaN      happy         happy
# 20         Google Chrome      Tablet        NaN      happy         happy
# 21       Mozilla Firefox      Mobile        NaN      happy         happy
# 22               Firefox      Mobile        NaN      happy         happy
# 23                  Edge      Mobile        NaN  not happy     not happy
# 24                  Edge      Mobile        NaN  not happy     not happy
# 25       Mozilla Firefox     Desktop        NaN  not happy     not happy
# 26               Mozilla      Tablet        NaN      happy         happy
# 27       Mozilla Firefox      Mobile        NaN  not happy     not happy
# 28     Internet Explorer      Mobile        NaN      happy         happy
# 29                  Edge      Mobile        NaN  not happy     not happy
# ...                  ...         ...        ...        ...           ...
# 29374               Edge     Desktop        NaN      happy     not happy
# 29375   InternetExplorer     Desktop        NaN  not happy     not happy
# 29376               Edge      Tablet        NaN  not happy     not happy
# 29377    Mozilla Firefox      Mobile        NaN      happy     not happy
# 29378   InternetExplorer      Mobile        NaN      happy         happy
# 29379               Edge      Tablet        NaN      happy     not happy
# 29380  Internet Explorer      Mobile        NaN      happy         happy
# 29381               Edge     Desktop        NaN  not happy     not happy
# 29382            Mozilla      Mobile        NaN  not happy     not happy
# 29383    Mozilla Firefox      Mobile        NaN      happy         happy
# 29384   InternetExplorer      Mobile        NaN      happy         happy
# 29385   InternetExplorer      Mobile        NaN  not happy     not happy
# 29386               Edge     Desktop        NaN  not happy     not happy
# 29387               Edge      Tablet        NaN      happy         happy
# 29388      Google Chrome     Desktop        NaN      happy         happy
# 29389               Edge      Tablet        NaN      happy         happy
# 29390   InternetExplorer      Mobile        NaN      happy         happy
# 29391    Mozilla Firefox      Mobile        NaN  not happy     not happy
# 29392      Google Chrome      Mobile        NaN      happy         happy
# 29393  Internet Explorer      Tablet        NaN      happy         happy
# 29394            Firefox     Desktop        NaN      happy         happy
# 29395               Edge      Mobile        NaN  not happy     not happy
# 29396            Firefox     Desktop        NaN      happy         happy
# 29397            Firefox      Tablet        NaN      happy         happy
# 29398            Mozilla      Mobile        NaN      happy         happy
# 29399             Chrome      Mobile        NaN      happy         happy
# 29400  Internet Explorer      Tablet        NaN      happy         happy
# 29401               Edge     Desktop        NaN      happy         happy
# 29402   InternetExplorer     Desktop        NaN      happy         happy
# 29403    Mozilla Firefox      Mobile        NaN      happy         happy
#
# [29404 rows x 7 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf_r = RandomForestClassifier()
clf_r.fit(train_features,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
pred = clf.predict(test_features)
data_test['predicted'] = pred

# %%
data_test.head()
# Out:
#    User_ID                                        Description  \
# 0  id80132  Looking for a motel in close proximity to TV t...
# 1  id80133  Walking distance to Madison Square Garden and ...
# 2  id80134  Visited Seattle on business. Spent - nights in...
# 3  id80135  This hotel location is excellent and the rooms...
# 4  id80136  This hotel is awesome I love the service Antho...
#
#        Browser_Used Device_Used Given_pred  predicted predicted_mlp
# 0           Firefox      Mobile      happy  not happy     not happy
# 1  InternetExplorer     Desktop  not_happy      happy         happy
# 2                IE      Tablet  not_happy      happy     not happy
# 3              Edge      Mobile  not_happy  not happy     not happy
# 4           Mozilla      Mobile      happy      happy         happy

# %% [markdown]
# ### NEED TO FIND BETTER APPROACH TO INCREASE THE SCORE
